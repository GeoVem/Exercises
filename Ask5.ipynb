# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %% [markdown]
# # (a)

# %% [markdown]
# ## (i)Gaussian Distribution

# %% [markdown]
# $$ f(x; \mu, \sigma)=\displaystyle \frac{1}{\sqrt{2\pi{}\sigma^2}}exp\left(-\frac{(x-\mu)^2}{\sigma^2}\right) $$

# %%
from scipy.stats import norm

# %%
mu = 1
sigma = 2
mean, var = norm.stats(loc=mu, scale=sigma, moments='mv')

# %%
x = np.linspace(norm.ppf(0.00001, mu, sigma), norm.ppf(0.99999, mu, sigma), 100)
plt.xlabel('x', fontsize=16)
plt.ylabel('f(x; μ=1, σ=2)')
plt.plot(x, norm.pdf(x, mu, sigma))

# %%
r = norm.rvs( mu, sigma , size = 1000 )

# %%
plt.figure(figsize=(8,8))
plt.hist(r, bins=100, density=False, histtype='step')
plt.xlabel('Normal Distribution', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Normal: n=1000, bins=100, σ=2, μ=1')
plt.show()

# %%
r = norm.rvs( mu, sigma , size = 1000 )

# %%
plt.figure(figsize=(15,8))
plt.hist(r, bins=50, density=False, histtype='step')
plt.xlabel('Normal Distribution', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Normal: n=1000, bins=50, σ=2, μ=1')
plt.show()

# %%
r = norm.rvs( mu, sigma , size = 500 )

# %%
plt.figure(figsize=(20,8))
plt.hist(r, bins=100, density=False, histtype='step')
plt.xlabel('Normal Distribution', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Normal: n=500, bins=100, σ=2, μ=1')
plt.show()

# %%
mu = 5
sigma = 3

# %%
r = norm.rvs( mu, sigma, size = 500 )

# %%
plt.figure(figsize=(20,8))
plt.hist(r, bins=100, density=False, histtype='step')
plt.xlabel('Normal Distribution', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Normal: n=500, bins=100, σ=3, μ=5')
plt.show()

# %%
r = norm.rvs( mu, sigma, size = 1000 )

# %%
plt.figure(figsize=(20,8))
plt.hist(r, bins=100, density=False, histtype='step')
plt.xlabel('Normal Distribution', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Normal: n=1000, bins=100, σ=3, μ=5')
plt.show()

# %% [markdown]
# ## (ii) Exponential Distribution

# %%
from scipy.stats import expon

# %% [markdown]
# $$ f(x; \lambda)= \lambda e^{-\lambda x}, \ x \geq 0 $$

# %%
lambdaa = 0.5

# %%
x = np.linspace(expon.ppf(0.00001), expon.ppf(0.9999), 100)
plt.xlabel('x', fontsize=16)
plt.ylabel('f(x; λ=0.5)')
plt.plot(x, expon.pdf(x), lambdaa , lw=1, alpha=0.5, label='expon pdf')

# %%
r1 = expon.rvs(lambdaa , size = 1000)

# %%
plt.figure(figsize=(15,8))
plt.hist(r1, bins=100, density=False, histtype='step')
plt.xlabel('Exponential Distribution', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Exp: n=1000, bins=100, λ=0.5')
plt.show()

# %%
r1 = expon.rvs(lambdaa , size = 1000)

# %%
plt.figure(figsize=(15,8))
plt.hist(r1, bins=50, density=False, histtype='step')
plt.xlabel('Exponential Distribution', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Exp: n=1000, bins=50, λ=0.5')
plt.show()

# %%
r1 = expon.rvs(lambdaa , size = 10000)

# %%
plt.figure(figsize=(15,8))
plt.hist(r1, bins=100, density=False, histtype='step')
plt.xlabel('Exponential Distribution', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Exp: n=10000, bins=100, λ=0.5')
plt.show()

# %%
lambdaa = 1.5

# %%
r1 = expon.rvs(lambdaa , size = 1000)

# %%
plt.figure(figsize=(20,10))
plt.hist(r1, bins=100, density=False, histtype='step')
plt.xlabel('Exponential Distribution', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Exp: n=1000, bins=100, λ=1.5')
plt.show()

# %% [markdown]
# ## (iii)Beta Distribution

# %% [markdown]
# $$ f(x;a,b)=\displaystyle \frac{\Gamma(a+b)x^{a-1}(1-x)^{b-1}}{\Gamma(a)\Gamma(b)}, \ 0 \leq x \leq 1$$

# %%
from scipy.stats import beta

# %%
a , b = 2.5 , 3.1

# %%
x = np.linspace(beta.ppf(0, a, b), beta.ppf(1, a, b), 100)
plt.xlabel('x', fontsize=16)
plt.ylabel('f(x; a=2.5 ,b=3.1)')
plt.plot(x, beta.pdf(x, a, b))

# %%
r2 = beta.rvs(a, b, size = 1000)

# %%
plt.figure(figsize=(20,8))
plt.hist(r2, bins=100, density=False, histtype='step')
plt.xlabel('Beta Distribution', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Beta: n=1000, bins=100, a=2.5, b=3.1')
plt.show()

# %%
r2 = beta.rvs(a, b, size = 1000)

# %%
plt.figure(figsize=(20,15))
plt.hist(r2, bins=50, density=False, histtype='step')
plt.xlabel('Beta Distribution', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Beta: n=1000, bins=50, a=2.5, b=3.1')
plt.show()

# %%
r2 = beta.rvs(a, b, size = 10000)

# %%
plt.figure(figsize=(20,15))
plt.hist(r2, bins=100, density=False, histtype='step')
plt.xlabel('Beta Distribution', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Beta: n=10000, bins=100, a=2.5, b=3.1')
plt.show()

# %%
a , b = 5.4 , 1.5

# %%
r2 = beta.rvs(a, b, size = 1000)

# %%
plt.figure(figsize=(25,20))
plt.hist(r2, bins=100, density=False, histtype='step')
plt.xlabel('Beta Distribution', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Beta: n=1000, bins=100, a=5.4, b=1.5')
plt.show()

# %% [markdown]
# # (b)

# %% [markdown]
# First we are going to combine the Normal Distribution with the exponential:

# %%
No_Exp = np.concatenate((r, r1))

# %%
plt.figure(figsize=(40,25))
plt.hist(No_Exp, bins=100, density=False, histtype='step')
plt.xlabel('Normal+Exponential Distributions', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Norm+Exp: n=2000, bins=100')
plt.show()

# %%
mean_value1 = np.mean(No_Exp)

# %%
mean_value1
# Out:
# 3.83265746039426

# %% [markdown]
# As we see this mean value does seem to be true from the histogram as well

# %% [markdown]
# Now we combine the exponential with the beta function:

# %%
Exp_Beta = np.concatenate((r1, r2))

# %%
plt.figure(figsize=(35,25))
plt.hist(Exp_Beta, bins=100, density=False, histtype='step')
plt.xlabel('Exponential+Beta Distributions', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Exp+Beta: n=2000, bins=100')
plt.show()

# %%
mean_value2 = np.mean(Exp_Beta)

# %%
mean_value2
# Out:
# 1.625899319057334

# %% [markdown]
# Again this mean value does seem to be correct as we can see from the histogram

# %% [markdown]
# Lasty we are going to combine the Beta distribution with the Normal:

# %%
Beta_Norm = np.concatenate((r2, r))

# %%
plt.figure(figsize=(35,25))
plt.hist(Beta_Norm, bins=100, density=False, histtype='step')
plt.xlabel('Beta+Normal Distributions', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Beta+Norm: n=2000, bins=100')
plt.show()

# %%
mean_value3 = np.mean(Beta_Norm)

# %%
mean_value3
# Out:
# 2.988708003857226

# %% [markdown]
# Of course, this mean value seems to be true again.

# %% [markdown]
# # (c)

# %% [markdown]
# ## Norm+Exp Distribution

# %%
random_choice1 = np.random.choice(No_Exp, 5)

# %%
random_choice1
# Out:
# array([ 2.47192644, 11.3889497 ,  2.41606221,  6.69286613,  1.58456602])

# %%
ran_mean_value1 = np.mean(random_choice1)

# %%
ran_mean_value1
# Out:
# 4.91087409887486

# %%
random_choice2 = np.random.choice(No_Exp, 5)

# %%
random_choice2
# Out:
# array([4.05700097, 8.55801204, 2.46617405, 1.84713428, 1.9489976 ])

# %%
ran_mean_value2 = np.mean(random_choice2)

# %%
ran_mean_value2
# Out:
# 3.77546378970981

# %%
random_choice3 = np.random.choice(No_Exp, 5)

# %%
random_choice3
# Out:
# array([2.1481872 , 2.82006921, 1.64428064, 6.33859211, 1.88630009])

# %%
ran_mean_value3 = np.mean(random_choice3)

# %%
ran_mean_value3
# Out:
# 2.967485849637784

# %% [markdown]
# Obviously we see that the mean value of the 5 generated random numbers changes everytime

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(10):
    random_choice = np.random.choice(No_Exp, 5)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)
    print (ran_mean_value)
# Out:
# 5.098891110302191
# 4.980121894330634
# 2.1337227068427636
# 3.84025281316285
# 3.4075928248454703
# 5.207614504788683
# 5.023345702312698
# 3.1377003991996517
# 5.60369826373573
# 3.328203890451948

# %%
b
# Out:
# array([5.09889111, 4.98012189, 2.13372271, 3.84025281, 3.40759282,
#        5.2076145 , 5.0233457 , 3.1377004 , 5.60369826, 3.32820389])

# %%
plt.figure(figsize=(15,10))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, linewidth = 0.5, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Norm+Exp Random mean values: 10 groups, 5 samples')
plt.show()

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(100):
    random_choice = np.random.choice(No_Exp, 5)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(20,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Norm+Exp Random mean values: 100 groups, 5 samples')
plt.show()

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(1000):
    random_choice = np.random.choice(No_Exp, 5)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(20,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Norm+Exp Random mean values: 1000 groups, 5 samples')
plt.show()

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(10000):
    random_choice = np.random.choice(No_Exp, 5)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(25,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Norm+Exp Random mean values: 10000 groups, 5 samples')
plt.show()

# %%
plt.figure(figsize=(25,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=100, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Norm+Exp Random mean values: 10000 groups, 5 samples')
plt.show()

# %% [markdown]
# ## Exp+Beta Distribution

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(10):
    random_choice = np.random.choice(Exp_Beta, 5)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
b
# Out:
# array([1.92896502, 1.13434953, 2.28344656, 1.7867499 , 1.48713139,
#        1.27642975, 2.15362539, 1.21368308, 1.47822444, 1.18646831])

# %%
plt.figure(figsize=(15,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Exp+Beta Random mean values: 10 groups, 5 samples')
plt.show()

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(100):
    random_choice = np.random.choice(Exp_Beta, 5)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(15,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Exp+Beta Random mean values: 100 groups, 5 samples')
plt.show()

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(1000):
    random_choice = np.random.choice(Exp_Beta, 5)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(15,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Exp+Beta Random mean values: 1000 groups, 5 samples')
plt.show()

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(10000):
    random_choice = np.random.choice(Exp_Beta, 5)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(15,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Exp+Beta Random mean values: 10000 groups, 5 samples')
plt.show()

# %%
plt.figure(figsize=(15,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=100, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Exp+Beta Random mean values: 10000 groups, 5 samples')
plt.show()

# %% [markdown]
# ## Beta+Normal Distribution

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(10):
    random_choice = np.random.choice(Beta_Norm, 5)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
b
# Out:
# array([3.82237509, 4.79848107, 1.08052497, 3.23437382, 2.38222707,
#        1.97055664, 4.30074625, 3.61101511, 4.23457609, 5.44559792])

# %%
plt.figure(figsize=(15,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Norm+Bea Random mean values: 10 groups, 5 samples')
plt.show()

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(100):
    random_choice = np.random.choice(Beta_Norm, 5)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(15,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Norm+Bea Random mean values: 100 groups, 5 samples')
plt.show()

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(1000):
    random_choice = np.random.choice(Beta_Norm, 5)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(15,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Norm+Bea Random mean values: 1000 groups, 5 samples')
plt.show()

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(10000):
    random_choice = np.random.choice(Beta_Norm, 5)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(15,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Norm+Bea Random mean values: 10000 groups, 5 samples')
plt.show()

# %%
plt.figure(figsize=(15,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=100, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Norm+Bea Random mean values: 10000 groups, 5 samples')
plt.show()

# %% [markdown]
# # (d)

# %% [markdown]
# ## Normal+Exp Distribution

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(100):
    random_choice = np.random.choice(No_Exp, 10)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(20,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Norm+Exp Random mean values: 100 groups, 10 samples')
plt.show()

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(1000):
    random_choice = np.random.choice(No_Exp, 20)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(20,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Norm+Exp Random mean values: 1000 groups, 20 samples')
plt.show()

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(10000):
    random_choice = np.random.choice(No_Exp, 50)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(20,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Norm+Exp Random mean values: 10000 groups, 50 samples')
plt.show()

# %%
plt.figure(figsize=(20,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=100, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Norm+Exp Random mean values: 10000 groups, 50 samples')
plt.show()

# %% [markdown]
# As expected the histograms do come close to the normal distribution as the samble and groups increase. Also the mean value is around 3.7 , as we found out in part (b)

# %% [markdown]
# ## Exp+Beta Distribution

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(100):
    random_choice = np.random.choice(Exp_Beta, 10)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(20,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Exp+Beta Random mean values: 100 groups, 10 samples')
plt.show()

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(1000):
    random_choice = np.random.choice(Exp_Beta, 20)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(20,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Exp_Beta Random mean values: 1000 groups, 20 samples')
plt.show()

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(10000):
    random_choice = np.random.choice(Exp_Beta, 50)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(20,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Exp_Beta Random mean values: 10000 groups, 50 samples')
plt.show()

# %%
plt.figure(figsize=(20,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=100, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Exp_Beta Random mean values: 10000 groups, 50 samples')
plt.show()

# %% [markdown]
# As expected the histograms do come close to the normal distribution as the samble and groups increase. Also the mean value is around 1.67 , as we found out in part (b)

# %% [markdown]
# ## Beta+Norm Distribution

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(100):
    random_choice = np.random.choice(Beta_Norm, 10)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(20,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Beta+Norm Random mean values: 100 groups, 10 samples')
plt.show()

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(1000):
    random_choice = np.random.choice(Beta_Norm, 20)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(20,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Beta+Norm Random mean values: 1000 groups, 20 samples')
plt.show()

# %%
a_empty = np.array([])
b = np.array([])

# %%
for i in range(10000):
    random_choice = np.random.choice(Beta_Norm, 50)
    ran_mean_value = np.mean(random_choice)
    a = np.append(a_empty, ran_mean_value)
    b = np.append(b, a)

# %%
plt.figure(figsize=(20,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=50, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Beta_Norm Random mean values: 10000 groups, 50 samples')
plt.show()

# %%
plt.figure(figsize=(20,12))
plt.style.use('seaborn-whitegrid')
plt.hist(b, bins=100, density=True, ec='black')
plt.xlabel('Mean Value', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Beta+Norm Random mean values: 10000 groups, 50 samples')
plt.show()

# %% [markdown]
# As expected the histograms do come close to the normal distribution as the samble and groups increase. Also the mean value is around 2.99 , as we found out in part (b)
